# %%
# Import the RL algorithm (Algorithm) we would like to use.
from ray.rllib.algorithms.ppo import PPO
from gym_flp.envs import ofpEnv

# %%
# Configure the algorithm.
config = {
    # Environment (RLlib understands openAI gym registered strings).
    "env": ofpEnv,
    "env_config": {
            "instance": "P6",
    },
    # Use 2 environment workers (aka "rollout workers") that parallelly
    # collect samples from their own environment clone(s).
    "num_workers": 1,
    # Change this to "framework: torch", if you are using PyTorch.
    # Also, use "framework: tf2" for tf2.x eager execution.
    "framework": "torch",
    # Tweak the default model provided automatically by RLlib,
    # given the environment's observation- and action spaces.
    "model": {
        "fcnet_hiddens": [64, 64],
        "fcnet_activation": "relu",
    },
    # Set up a separate evaluation worker set for the
    # `algo.evaluate()` call after training (see below).
    "evaluation_num_workers": 1,
    # Only for evaluation runs, render the env.
    "evaluation_config": {
        "render_env": True,
    },
}

# %%
# Create our RLlib Trainer.
algo = PPO(config=config)
# Out:
# 2022-10-16 21:23:29,143	WARNING algorithm.py:2099 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Trainer.train()`. Instead, you will have to call `Trainer.evaluate()` manually in order to trigger an evaluation run.
# (RolloutWorker pid=7344) Available Problem Sets: dict_keys(['AB20', 'AEG20', 'AML4', 'BA12', 'BA14', 'BME15', 'D10', 'D12', 'D6', 'D8', 'FO10', 'FO11', 'FO7', 'FO8', 'FO9', 'LW11', 'LW5', 'O10', 'O12', 'O7', 'O8', 'O9', 'P12', 'P15', 'P20', 'P30', 'P4', 'P6', 'P62', 'S8', 'S8H', 'S9', 'S9H', 'SC30', 'SC35', 'TAM20', 'TAM30', 'TL12', 'TL15', 'TL20', 'TL30', 'TL5', 'TL6', 'TL7', 'TL8', 'VC10', 'WA7', 'WG12', 'WG6'])
# (RolloutWorker pid=7344) Pick a problem:
# (RolloutWorker pid=7344) 2022-10-16 21:23:34,680	ERROR worker.py:756 -- Exception raised in creation task: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=7344, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001B607333490>)
# (RolloutWorker pid=7344)   File "python\ray\_raylet.pyx", line 662, in ray._raylet.execute_task
# (RolloutWorker pid=7344)   File "python\ray\_raylet.pyx", line 666, in ray._raylet.execute_task
# (RolloutWorker pid=7344)   File "python\ray\_raylet.pyx", line 613, in ray._raylet.execute_task.function_executor
# (RolloutWorker pid=7344)   File "c:\users\hhb\pycharmprojects\gym-flp\venv\lib\site-packages\ray\_private\function_manager.py", line 674, in actor_method_executor
# (RolloutWorker pid=7344)     return method(__ray_actor, *args, **kwargs)
# (RolloutWorker pid=7344)   File "c:\users\hhb\pycharmprojects\gym-flp\venv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 466, in _resume_span
# (RolloutWorker pid=7344)     return method(self, *_args, **_kwargs)
# (RolloutWorker pid=7344)   File "c:\users\hhb\pycharmprojects\gym-flp\venv\lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 490, in __init__
# (RolloutWorker pid=7344)     self.env = env_creator(copy.deepcopy(self.env_context))
# (RolloutWorker pid=7344)   File "c:\users\hhb\pycharmprojects\gym-flp\venv\lib\site-packages\ray\rllib\algorithms\algorithm.py", line 1707, in <lambda>
# (RolloutWorker pid=7344)     return env_id, lambda cfg: env_specifier(cfg)
# (RolloutWorker pid=7344)   File "C:\Users\HHB\PycharmProjects\gym-flp\gym_flp\envs\flp_env.py", line 466, in __init__
# (RolloutWorker pid=7344)     self.instance = input('Pick a problem:').strip()
# (RolloutWorker pid=7344) EOFError: EOF when reading a line
# ---------------------------------------------------------------------------
# RayActorError                             Traceback (most recent call last)
# File c:\users\hhb\pycharmprojects\gym-flp\venv\lib\site-packages\ray\rllib\algorithms\algorithm.py:418, in Algorithm.setup(self, config)
#     417 try:
# --> 418     self.workers = WorkerSet(
#     419         env_creator=self.env_creator,
#     420         validate_env=self.validate_env,
#     421         policy_class=self.get_default_policy_class(self.config),
#     422         trainer_config=self.config,
#     423         num_workers=self.config["num_workers"],
#     424         local_worker=True,
#     425         logdir=self.logdir,
#     426     )
#     427 # WorkerSet creation possibly fails, if some (remote) workers cannot
#     428 # be initialized properly (due to some errors in the RolloutWorker's
#     429 # constructor).
#
# File c:\users\hhb\pycharmprojects\gym-flp\venv\lib\site-packages\ray\rllib\evaluation\worker_set.py:125, in WorkerSet.__init__(self, env_creator, validate_env, policy_class, trainer_config, num_workers, local_worker, logdir, _setup)
#     124 self._remote_workers = []
# --> 125 self.add_workers(
#     126     num_workers,
#     127     validate=trainer_config.get("validate_workers_after_construction"),
#     128 )
#     130 # Create a local worker, if needed.
#     131 # If num_workers > 0 and we don't have an env on the local worker,
#     132 # get the observation- and action spaces for each policy from
#     133 # the first remote worker (which does have an env).
#
# File c:\users\hhb\pycharmprojects\gym-flp\venv\lib\site-packages\ray\rllib\evaluation\worker_set.py:269, in WorkerSet.add_workers(self, num_workers, validate)
#     268 if validate:
# --> 269     self.foreach_worker(lambda w: w.assert_healthy())
#
# File c:\users\hhb\pycharmprojects\gym-flp\venv\lib\site-packages\ray\rllib\evaluation\worker_set.py:391, in WorkerSet.foreach_worker(self, func)
#     390     local_result = [func(self.local_worker())]
# --> 391 remote_results = ray.get([w.apply.remote(func) for w in self.remote_workers()])
#     392 return local_result + remote_results
#
# File c:\users\hhb\pycharmprojects\gym-flp\venv\lib\site-packages\ray\_private\client_mode_hook.py:105, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     104         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105 return func(*args, **kwargs)
#
# File c:\users\hhb\pycharmprojects\gym-flp\venv\lib\site-packages\ray\_private\worker.py:2277, in get(object_refs, timeout)
#    2276         else:
# -> 2277             raise value
#    2279 if is_individual_id:
#
# RayActorError: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=7344, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001B607333490>)
#   File "python\ray\_raylet.pyx", line 662, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 666, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 613, in ray._raylet.execute_task.function_executor
#   File "c:\users\hhb\pycharmprojects\gym-flp\venv\lib\site-packages\ray\_private\function_manager.py", line 674, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "c:\users\hhb\pycharmprojects\gym-flp\venv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "c:\users\hhb\pycharmprojects\gym-flp\venv\lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 490, in __init__
#     self.env = env_creator(copy.deepcopy(self.env_context))
#   File "c:\users\hhb\pycharmprojects\gym-flp\venv\lib\site-packages\ray\rllib\algorithms\algorithm.py", line 1707, in <lambda>
#     return env_id, lambda cfg: env_specifier(cfg)
#   File "C:\Users\HHB\PycharmProjects\gym-flp\gym_flp\envs\flp_env.py", line 466, in __init__
#     self.instance = input('Pick a problem:').strip()
# EOFError: EOF when reading a line
#
# During handling of the above exception, another exception occurred:
#
# EOFError                                  Traceback (most recent call last)
# Cell In [17], line 2
#       1 # Create our RLlib Trainer.
# ----> 2 algo = PPO(config=config)
#
# File c:\users\hhb\pycharmprojects\gym-flp\venv\lib\site-packages\ray\rllib\algorithms\algorithm.py:308, in Algorithm.__init__(self, config, env, logger_creator, **kwargs)
#     296 # Initialize common evaluation_metrics to nan, before they become
#     297 # available. We want to make sure the metrics are always present
#     298 # (although their values may be nan), so that Tune does not complain
#     299 # when we use these as stopping criteria.
#     300 self.evaluation_metrics = {
#     301     "evaluation": {
#     302         "episode_reward_max": np.nan,
#    (...)
#     305     }
#     306 }
# --> 308 super().__init__(config=config, logger_creator=logger_creator, **kwargs)
#     310 # Check, whether `training_iteration` is still a tune.Trainable property
#     311 # and has not been overridden by the user in the attempt to implement the
#     312 # algos logic (this should be done now inside `training_step`).
#     313 try:
#
# File c:\users\hhb\pycharmprojects\gym-flp\venv\lib\site-packages\ray\tune\trainable\trainable.py:157, in Trainable.__init__(self, config, logger_creator, remote_checkpoint_dir, custom_syncer)
#     155 start_time = time.time()
#     156 self._local_ip = self.get_current_ip()
# --> 157 self.setup(copy.deepcopy(self.config))
#     158 setup_time = time.time() - start_time
#     159 if setup_time > SETUP_TIME_THRESHOLD:
#
# File c:\users\hhb\pycharmprojects\gym-flp\venv\lib\site-packages\ray\rllib\algorithms\algorithm.py:443, in Algorithm.setup(self, config)
#     430 except RayActorError as e:
#     431     # In case of an actor (remote worker) init failure, the remote worker
#     432     # may still exist and will be accessible, however, e.g. calling
#     433     # its `sample.remote()` would result in strange "property not found"
#     434     # errors.
#     435     if e.actor_init_failed:
#     436         # Raise the original error here that the RolloutWorker raised
#     437         # during its construction process. This is to enforce transparency
#    (...)
#     441         # - e.args[0].args[2]: The original Exception (e.g. a ValueError due
#     442         # to a config mismatch) thrown inside the actor.
# --> 443         raise e.args[0].args[2]
#     444     # In any other case, raise the RayActorError as-is.
#     445     else:
#     446         raise e
#
# EOFError: EOF when reading a line

# %%
# Run it for n training iterations. A training iteration includes
# parallel sample collection by the environment workers as well as
# loss calculation on the collected batch and a model update.
for _ in range(3):
    print(algo.train())
# Out:
# {'custom_metrics': {}, 'episode_media': {}, 'num_recreated_workers': 0, 'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 0.0993564332324651, 'cur_kl_coeff': 0.20000000000000004, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.957814631923553, 'policy_loss': 0.011408035224303604, 'vf_loss': 9.946266718833677, 'vf_explained_var': 1.5166754363685527e-05, 'kl': 0.0006992249980204189, 'entropy': 1.7910642288064444, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 128.0}}, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000}, 'sampler_results': {'episode_reward_max': -677.0, 'episode_reward_min': -893.0, 'episode_reward_mean': -773.3, 'episode_len_mean': 200.0, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-758.0, -830.0, -740.0, -722.0, -830.0, -731.0, -722.0, -776.0, -749.0, -821.0, -857.0, -740.0, -740.0, -794.0, -893.0, -830.0, -776.0, -704.0, -677.0, -776.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.2701269394752086, 'mean_inference_ms': 0.8466210381976371, 'mean_action_processing_ms': 0.05906275187296487, 'mean_env_wait_ms': 0.043296504175585546, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0}, 'episode_reward_max': -677.0, 'episode_reward_min': -893.0, 'episode_reward_mean': -773.3, 'episode_len_mean': 200.0, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'hist_stats': {'episode_reward': [-758.0, -830.0, -740.0, -722.0, -830.0, -731.0, -722.0, -776.0, -749.0, -821.0, -857.0, -740.0, -740.0, -794.0, -893.0, -830.0, -776.0, -704.0, -677.0, -776.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.2701269394752086, 'mean_inference_ms': 0.8466210381976371, 'mean_action_processing_ms': 0.05906275187296487, 'mean_env_wait_ms': 0.043296504175585546, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'num_healthy_workers': 2, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'timesteps_total': 4000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 4000, 'timers': {'training_iteration_time_ms': 7937.413, 'load_time_ms': 1.99, 'load_throughput': 2009728.797, 'learn_time_ms': 5367.795, 'learn_throughput': 745.185, 'synch_weights_time_ms': 2.049}, 'counters': {'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000}, 'done': False, 'episodes_total': 20, 'training_iteration': 1, 'trial_id': 'default', 'experiment_id': '1b113bfd452e48b7b56ba72e4fcfcdf1', 'date': '2022-10-16_21-12-09', 'timestamp': 1665947529, 'time_this_iter_s': 7.94363260269165, 'time_total_s': 7.94363260269165, 'pid': 9660, 'hostname': 'NB00521', 'node_ip': '127.0.0.1', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'num_gpus': 0, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, '_fake_gpus': False, 'custom_resources_per_worker': {}, 'placement_strategy': 'PACK', 'eager_tracing': False, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'env': 'Taxi-v3', 'env_config': {}, 'observation_space': None, 'a ...
# {'custom_metrics': {}, 'episode_media': {}, 'num_recreated_workers': 0, 'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 0.17173803750305405, 'cur_kl_coeff': 0.10000000000000002, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.890766992876607, 'policy_loss': 0.0015649036023645633, 'vf_loss': 9.888455752916233, 'vf_explained_var': 5.50127798511136e-05, 'kl': 0.007463001345008808, 'entropy': 1.772368324059312, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 128.0}}, 'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000}, 'sampler_results': {'episode_reward_max': -361.0, 'episode_reward_min': -893.0, 'episode_reward_mean': -721.75, 'episode_len_mean': 197.05, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-758.0, -830.0, -740.0, -722.0, -830.0, -731.0, -722.0, -776.0, -749.0, -821.0, -857.0, -740.0, -740.0, -794.0, -893.0, -830.0, -776.0, -704.0, -677.0, -776.0, -659.0, -767.0, -749.0, -722.0, -785.0, -542.0, -596.0, -650.0, -686.0, -659.0, -695.0, -551.0, -731.0, -785.0, -361.0, -704.0, -695.0, -695.0, -740.0, -632.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 185, 200, 200, 200, 200, 200, 176, 200, 200, 121, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.26670179512158276, 'mean_inference_ms': 0.8357256334798988, 'mean_action_processing_ms': 0.05548013364585118, 'mean_env_wait_ms': 0.04270120554044676, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0}, 'episode_reward_max': -361.0, 'episode_reward_min': -893.0, 'episode_reward_mean': -721.75, 'episode_len_mean': 197.05, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'hist_stats': {'episode_reward': [-758.0, -830.0, -740.0, -722.0, -830.0, -731.0, -722.0, -776.0, -749.0, -821.0, -857.0, -740.0, -740.0, -794.0, -893.0, -830.0, -776.0, -704.0, -677.0, -776.0, -659.0, -767.0, -749.0, -722.0, -785.0, -542.0, -596.0, -650.0, -686.0, -659.0, -695.0, -551.0, -731.0, -785.0, -361.0, -704.0, -695.0, -695.0, -740.0, -632.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 185, 200, 200, 200, 200, 200, 176, 200, 200, 121, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.26670179512158276, 'mean_inference_ms': 0.8357256334798988, 'mean_action_processing_ms': 0.05548013364585118, 'mean_env_wait_ms': 0.04270120554044676, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'num_healthy_workers': 2, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000, 'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'timesteps_total': 8000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 8000, 'timers': {'training_iteration_time_ms': 7784.742, 'load_time_ms': 1.492, 'load_throughput': 2681780.051, 'learn_time_ms': 5312.491, 'learn_throughput': 752.942, 'synch_weights_time_ms': 2.522}, 'counters': {'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000}, 'done': False, 'episodes_total': 40, 'training_iteration': 2, 'trial_id': 'default', 'experiment_id': '1b113bfd452e48b7b56ba72e4fcfcdf1', 'date': '2022-10-16_21-12-16', 'timestamp': 1665947536, 'time_this_iter_s': 7.637814283370972, 'time_total_s': 15.581446886062622, 'pid': 9660, 'hostname': 'NB00521', 'node_ip': '127.0.0.1', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'num_gpus': 0, 'num_cpus_per_worker': 1, 'num_gpus_per_wor ...
# {'custom_metrics': {}, 'episode_media': {}, 'num_recreated_workers': 0, 'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 0.2960163688066826, 'cur_kl_coeff': 0.10000000000000002, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.777384577515305, 'policy_loss': -0.003194568738822014, 'vf_loss': 9.779718984583372, 'vf_explained_var': -4.832738189287083e-05, 'kl': 0.008601751676811736, 'entropy': 1.7228780158104435, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 128.0}}, 'num_env_steps_sampled': 12000, 'num_env_steps_trained': 12000, 'num_agent_steps_sampled': 12000, 'num_agent_steps_trained': 12000}, 'sampler_results': {'episode_reward_max': -206.0, 'episode_reward_min': -893.0, 'episode_reward_mean': -661.2295081967213, 'episode_len_mean': 193.72131147540983, 'episode_media': {}, 'episodes_this_iter': 21, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-758.0, -830.0, -740.0, -722.0, -830.0, -731.0, -722.0, -776.0, -749.0, -821.0, -857.0, -740.0, -740.0, -794.0, -893.0, -830.0, -776.0, -704.0, -677.0, -776.0, -659.0, -767.0, -749.0, -722.0, -785.0, -542.0, -596.0, -650.0, -686.0, -659.0, -695.0, -551.0, -731.0, -785.0, -361.0, -704.0, -695.0, -695.0, -740.0, -632.0, -533.0, -632.0, -587.0, -551.0, -578.0, -560.0, -551.0, -659.0, -560.0, -569.0, -614.0, -677.0, -569.0, -299.0, -632.0, -542.0, -206.0, -578.0, -340.0, -623.0, -605.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 185, 200, 200, 200, 200, 200, 176, 200, 200, 121, 200, 200, 200, 200, 200, 200, 200, 200, 194, 200, 200, 200, 200, 200, 200, 200, 200, 200, 113, 200, 200, 92, 200, 136, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.2660349671786276, 'mean_inference_ms': 0.829459352172166, 'mean_action_processing_ms': 0.05331399704797807, 'mean_env_wait_ms': 0.04234544814714394, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0}, 'episode_reward_max': -206.0, 'episode_reward_min': -893.0, 'episode_reward_mean': -661.2295081967213, 'episode_len_mean': 193.72131147540983, 'episodes_this_iter': 21, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'hist_stats': {'episode_reward': [-758.0, -830.0, -740.0, -722.0, -830.0, -731.0, -722.0, -776.0, -749.0, -821.0, -857.0, -740.0, -740.0, -794.0, -893.0, -830.0, -776.0, -704.0, -677.0, -776.0, -659.0, -767.0, -749.0, -722.0, -785.0, -542.0, -596.0, -650.0, -686.0, -659.0, -695.0, -551.0, -731.0, -785.0, -361.0, -704.0, -695.0, -695.0, -740.0, -632.0, -533.0, -632.0, -587.0, -551.0, -578.0, -560.0, -551.0, -659.0, -560.0, -569.0, -614.0, -677.0, -569.0, -299.0, -632.0, -542.0, -206.0, -578.0, -340.0, -623.0, -605.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 185, 200, 200, 200, 200, 200, 176, 200, 200, 121, 200, 200, 200, 200, 200, 200, 200, 200, 194, 200, 200, 200, 200, 200, 200, 200, 200, 200, 113, 200, 200, 92, 200, 136, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.2660349671786276, 'mean_inference_ms': 0.829459352172166, 'mean_action_processing_ms': 0.05331399704797807, 'mean_env_wait_ms': 0.04234544814714394, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'num_healthy_workers': 2, 'num_agent_steps_sampled': 12000, 'num_agent_steps_trained': 12000, 'num_env_steps_sampled': 12000, 'num_env_steps_trained': 12000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'timesteps_total': 12000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 12000, 'timers': {'training_iteration_time_ms': 7697.214, 'load_time_ms': 1.344, 'load_throughput': 2976266.809, 'learn_time_ms': 5248.511, 'learn_throughput': 762.121, 'synch_weights_time_ms': 2.674}, 'counters': {'num_env_ ...

# %%
# Evaluate the trained Trainer (and render each timestep to the shell's
# output).
algo.evaluate()
# Out:
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) |_: | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | :_| : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) |_: | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) |_: | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) |_: | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) |_: | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R:_| : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R:_| : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R:_| : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | :_| : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# ...
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (South)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Dropoff)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (Pickup)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (West)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (North)
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344) |R: | : :G|
# (RolloutWorker pid=13344) | : | : : |
# (RolloutWorker pid=13344) | : : : : |
# (RolloutWorker pid=13344) | | : | : |
# (RolloutWorker pid=13344) |Y| : |B: |
# (RolloutWorker pid=13344) +---------+
# (RolloutWorker pid=13344)   (East)
# {'evaluation': {'episode_reward_max': -233.0,
#   'episode_reward_min': -641.0,
#   'episode_reward_mean': -519.2,
#   'episode_len_mean': 195.5,
#   'episode_media': {},
#   'episodes_this_iter': 10,
#   'policy_reward_min': {},
#   'policy_reward_max': {},
#   'policy_reward_mean': {},
#   'custom_metrics': {},
#   'hist_stats': {'episode_reward': [-551.0,
#     -497.0,
#     -641.0,
#     -233.0,
#     -578.0,
#     -524.0,
#     -479.0,
#     -515.0,
#     -614.0,
#     -560.0],
#    'episode_lengths': [200, 200, 200, 155, 200, 200, 200, 200, 200, 200]},
#   'sampler_perf': {'mean_raw_obs_processing_ms': 0.2953185869384641,
#    'mean_inference_ms': 1.0057994924439977,
#    'mean_action_processing_ms': 0.05157922674541825,
#    'mean_env_wait_ms': 0.057617335719321164,
#    'mean_env_render_ms': 0.13220553992959866},
#   'num_faulty_episodes': 0,
#   'num_agent_steps_sampled_this_iter': 1955,
#   'num_env_steps_sampled_this_iter': 1955,
#   'timesteps_this_iter': 1955}}
